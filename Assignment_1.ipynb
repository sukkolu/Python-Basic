# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# ```
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
# ```

# %% [markdown]
# Ans.
# ```
# String| hello
# Integer|6
# Floating point number| -87.8
# Mathematical Operators| * / - +
#
# ```

# %% [markdown]
# 2. What is the difference between string and variable?

# %% [markdown]
# Ans. a) String:- String is a data type in a python. String is a sequence of character inclosed in quotes.
#
# b) Variable:- A variable is the name given to a memory in locaction in a program. For example:- A= 30 b="Rama" etc.

# %% [markdown]
# 3. Describe three different data types.

# %% [markdown]
# Ans. primarly there are following data type in python
# ```
# 1) Integers ↪ Whole numbers such as 3, 700, 899 etc.
# 2) Floating point numbers ↪ Number with decimal point 2.4, 1.7 etc.
# 3) Strings ↪ String is a data type in a python. String is a sequence of character inclosed in quotes.
# 4) Booleans ↪ Logical value indication True or Flase.
# ```

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# Ans. A combination of operands and operators is called an expression. The expression in Python produces some value or result after being interpreted by the Python interpreter. An expression in Python is a combination of operators and operands.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [markdown]
# Ans.
#
# ```
# x = 25          # a statement
# x = x + 10      # an expression
#
# print(x)
# ```

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %%
bacon
# Out:
# 22

# %% [markdown]
# 7. What should the values of the following two terms be?

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Ans:-
# ```
# 1) eggs is valid variable name because should be start with alphabates.
# 2) 100 is not a valid variable bacause variable name contain number but can't start with number.
# ```

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %% [markdown]
# Ans. The int() , float() , and str( ) functions will evaluate to the integer, floating-point number, and string versions of the value passed to them.

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?

# %%
'I have eaten' + 99 +  'burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-46142e25f53c> in <module>
# ----> 1 'I have eaten' + 99 +  'burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# It's a TypeError only cancatenate string data type with string  only.
# We can use 99 as string by using '99' quote.

# %%
'I have eaten' + '99' +  'burritos.'
# Out:
# 'I have eaten99burritos.'
